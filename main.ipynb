# %%
import pandas as pd

datos_user = "datos-andres-nuevo"
saltarse = 10

datos_x_cpu = pd.read_csv(f'actividad-2/{datos_user}/cpu_stats.csv')
datos_x_cpu
# Out:
#         ID            Timestamp  %CPU (global)  %CPU (user)  %CPU(system)
# 0        0  2025-03-09 17:47:07            2.0          0.7           1.3
# 1        1  2025-03-09 17:47:12            2.0          0.7           1.4
# 2        2  2025-03-09 17:47:17            1.4          0.7           0.7
# 3        3  2025-03-09 17:47:23            2.0          0.7           1.4
# 4        4  2025-03-09 17:47:28            1.4          0.7           0.7
# ...    ...                  ...            ...          ...           ...
# 1075  1075  2025-03-09 19:21:37            1.4          0.7           0.7
# 1076  1076  2025-03-09 19:21:42            2.1          0.7           1.4
# 1077  1077  2025-03-09 19:21:48            1.4          0.7           0.7
# 1078  1078  2025-03-09 19:21:53            1.4          0.7           0.7
# 1079  1079  2025-03-09 19:21:58            1.4          0.7           0.7
#
# [1080 rows x 5 columns]

# %%
# Limpiamos los primeros 5 registros, para que no afecten el análisis
datos_x_cpu = datos_x_cpu[saltarse:]
datos_x_cpu
# Out:
#         ID            Timestamp  %CPU (global)  %CPU (user)  %CPU(system)
# 10      10  2025-03-09 17:48:00            1.9          0.6           1.3
# 11      11  2025-03-09 17:48:05            2.0          0.7           1.3
# 12      12  2025-03-09 17:48:10            2.8          2.1           0.7
# 13      13  2025-03-09 17:48:15            1.4          0.7           0.7
# 14      14  2025-03-09 17:48:21            1.4          0.7           0.7
# ...    ...                  ...            ...          ...           ...
# 1075  1075  2025-03-09 19:21:37            1.4          0.7           0.7
# 1076  1076  2025-03-09 19:21:42            2.1          0.7           1.4
# 1077  1077  2025-03-09 19:21:48            1.4          0.7           0.7
# 1078  1078  2025-03-09 19:21:53            1.4          0.7           0.7
# 1079  1079  2025-03-09 19:21:58            1.4          0.7           0.7
#
# [1070 rows x 5 columns]

# %%
# mean of %CPU (global), %CPU (user), %CPU (system)
mean_cpu_global = datos_x_cpu["%CPU (global)"].mean()
mean_cpu_user = datos_x_cpu["%CPU (user)"].mean()
mean_cpu_system = datos_x_cpu["%CPU(system)"].mean()

# max of %CPU (global), %CPU (user), %CPU (system)
max_cpu_global = datos_x_cpu["%CPU (global)"].max()
max_cpu_user = datos_x_cpu["%CPU (user)"].max()
max_cpu_system = datos_x_cpu["%CPU(system)"].max()

# min of %CPU (global), %CPU (user), %CPU (system)
min_cpu_global = datos_x_cpu["%CPU (global)"].min()
min_cpu_user = datos_x_cpu["%CPU (user)"].min()
min_cpu_system = datos_x_cpu["%CPU(system)"].min()

# std of %CPU (global), %CPU (user), %CPU (system)
std_cpu_global = datos_x_cpu["%CPU (global)"].std()
std_cpu_user = datos_x_cpu["%CPU (user)"].std()
std_cpu_system = datos_x_cpu["%CPU(system)"].std()

print("mean of %CPU (global):", mean_cpu_global)
print("mean of %CPU (user):", mean_cpu_user)
print("mean of %CPU (system):", mean_cpu_system)
print("max of %CPU (global):", max_cpu_global)
print("max of %CPU (user):", max_cpu_user)
print("max of %CPU (system):", max_cpu_system)
print("min of %CPU (global):", min_cpu_global)
print("min of %CPU (user):", min_cpu_user)
print("min of %CPU (system):", min_cpu_system)
print("std of %CPU (global):", std_cpu_global)
print("std of %CPU (user):", std_cpu_user)
print("std of %CPU (system):", std_cpu_system)
# Out:
# mean of %CPU (global): 1.4853271028037383
# mean of %CPU (user): 0.5436448598130842
# mean of %CPU (system): 0.942429906542056
# max of %CPU (global): 11.9
# max of %CPU (user): 3.7
# max of %CPU (system): 7.5
# min of %CPU (global): 0.0
# min of %CPU (user): 0.0
# min of %CPU (system): 0.0
# std of %CPU (global): 0.5435906292699858
# std of %CPU (user): 0.34341566237216875
# std of %CPU (system): 0.40383299422471675

# %%
import matplotlib.pyplot as plt

span = 15

# Ahora en una grafica
plt.title("CPU stats")
plt.xlabel("Tiempo (s)")
plt.ylabel("Porcentaje de uso (%)")
plt.plot(datos_x_cpu["%CPU (global)"].ewm(span=span).mean(), label="%CPU (global)")
plt.plot(datos_x_cpu["%CPU (user)"].ewm(span=span).mean(), label="%CPU (user)")
plt.plot(datos_x_cpu["%CPU(system)"].ewm(span=span).mean(), label="%CPU (system)")
plt.legend()

plt.show()

# %%
datos_x_memoria = pd.read_csv(f'actividad-2/{datos_user}/memory_stats.csv')
datos_x_memoria

# Limpiamos los primeros 5 registros, para que no afecten el análisis
datos_x_memoria = datos_x_memoria[saltarse:]

# %%
# Utilizacion media de Capacidad utilizada y % Memoria utilizada
mean_capacidad_utilizada = datos_x_memoria["Capacidad utilizada"].mean()
mean_memoria_utilizada = datos_x_memoria["% Memoria utilizada"].mean()

# Maximo de Capacidad utilizada y % Memoria utilizada
max_capacidad_utilizada = datos_x_memoria["Capacidad utilizada"].max()
max_memoria_utilizada = datos_x_memoria["% Memoria utilizada"].max()

# Minimo de Capacidad utilizada y % Memoria utilizada
min_capacidad_utilizada = datos_x_memoria["Capacidad utilizada"].min()
min_memoria_utilizada = datos_x_memoria["% Memoria utilizada"].min()

print("mean of Capacidad utilizada:", mean_capacidad_utilizada)
print("mean of % Memoria utilizada:", mean_memoria_utilizada)
print("max of Capacidad utilizada:", max_capacidad_utilizada)
print("max of % Memoria utilizada:", max_memoria_utilizada)
print("min of Capacidad utilizada:", min_capacidad_utilizada)
print("min of % Memoria utilizada:", min_memoria_utilizada)
# Out:
# mean of Capacidad utilizada: 1084207.3359331477
# mean of % Memoria utilizada: 13.414828495821727
# max of Capacidad utilizada: 1117204
# max of % Memoria utilizada: 13.8231
# min of Capacidad utilizada: 1070680
# min of % Memoria utilizada: 13.2475

# %%
# Para el primer gráfico
max_value_capacidad = datos_x_memoria["Capacidad utilizada"].max()
plt.title("Memory stats")
plt.xlabel("Tiempo (s)")
plt.ylabel("Capacidad utilizada (MB)")
plt.plot(datos_x_memoria["Capacidad utilizada"].ewm(span=span).mean(), label="Capacidad utilizada")
plt.ylim(bottom=0, top=max_value_capacidad * 1.2)  # Añade un 20% extra al máximo
plt.legend()
plt.show()

# Para el segundo gráfico
plt.title("Memory stats")
plt.xlabel("Tiempo (s)")
plt.ylabel("Porcentaje de uso (%)")
plt.plot(datos_x_memoria["% Memoria utilizada"].ewm(span=span).mean(), label="% Memoria utilizada")
plt.ylim(bottom=0, top=100)
plt.legend()
plt.show()

# %%
# Ahora cpu_adn_memory_stats.csv
datos_x_cpu_memoria = pd.read_csv(f'actividad-2/{datos_user}/cpu_and_memory_stats.csv')
datos_x_cpu_memoria

# Limpiamos los primeros 5 registros, para que no afecten el análisis
datos_x_cpu_memoria = datos_x_cpu_memoria[saltarse:]

# %%
# mean of %CPU (global), Capacidad de memoria utilizada y % Memoria utilizada
mean_cpu_global = datos_x_cpu_memoria["%CPU (global)"].mean()
mean_capacidad_utilizada = datos_x_cpu_memoria["Capacidad de memoria utilizada"].mean()
mean_memoria_utilizada = datos_x_cpu_memoria["% Memoria utilizada"].mean()

# Max of %CPU (global), Capacidad de memoria utilizada y % Memoria utilizada
max_cpu_global = datos_x_cpu_memoria["%CPU (global)"].max()
max_capacidad_utilizada = datos_x_cpu_memoria["Capacidad de memoria utilizada"].max()
max_memoria_utilizada = datos_x_cpu_memoria["% Memoria utilizada"].max()

# Min of %CPU (global), Capacidad de memoria utilizada y % Memoria utilizada
min_cpu_global = datos_x_cpu_memoria["%CPU (global)"].min()
min_capacidad_utilizada = datos_x_cpu_memoria["Capacidad de memoria utilizada"].min()
min_memoria_utilizada = datos_x_cpu_memoria["% Memoria utilizada"].min()

print("mean of %CPU (global):", mean_cpu_global)
print("mean of Capacidad utilizada:", mean_capacidad_utilizada)
print("mean of % Memoria utilizada:", mean_memoria_utilizada)
print("max of %CPU (global):", max_cpu_global)
print("max of Capacidad utilizada:", max_capacidad_utilizada)
print("max of % Memoria utilizada:", max_memoria_utilizada)
print("min of %CPU (global):", min_cpu_global)
print("min of Capacidad utilizada:", min_capacidad_utilizada)
print("min of % Memoria utilizada:", min_memoria_utilizada)
# Out:
# mean of %CPU (global): 1.4494405594405593
# mean of Capacidad utilizada: 1839336.46993007
# mean of % Memoria utilizada: 26.31193251748252
# max of %CPU (global): 4.2
# max of Capacidad utilizada: 1844080
# max of % Memoria utilizada: 26.4035
# min of %CPU (global): 0.0
# min of Capacidad utilizada: 1835340
# min of % Memoria utilizada: 26.2255

# %%
# Ahora en una grafica
plt.title("CPU and Memory stats")
plt.xlabel("Tiempo (s)")
plt.ylabel("Porcentaje de uso (%)")
plt.plot(datos_x_cpu_memoria["%CPU (global)"].ewm(span=span).mean(), label="%CPU (global)")
plt.plot(datos_x_cpu_memoria["% Memoria utilizada"].ewm(span=span).mean(), label="% Memoria utilizada")
plt.ylim(bottom=0, top=100)
plt.legend()
plt.show()

# Ahora en una grafica, y empieza en 0

max_value_capacidad = datos_x_cpu_memoria["Capacidad de memoria utilizada"].max()
plt.figure()
plt.title("CPU and Memory stats")
plt.xlabel("Tiempo (s)")
plt.ylabel("Capacidad de memoria utilizada (MB)")
plt.plot(datos_x_cpu_memoria["Capacidad de memoria utilizada"].ewm(span=span).mean(), label="Capacidad de memoria utilizada")
plt.ylim(bottom=0, top=max_value_capacidad*1.2)
plt.legend()
plt.show()

# # Gráfica con la diferencia mínima
# plt.figure()
# plt.title("CPU and Memory stats")
# plt.xlabel("Tiempo (s)")
# plt.ylabel("Capacidad de memoria utilizada (MB)")
# plt.plot(datos_x_cpu_memoria["Capacidad de memoria utilizada"].ewm(span=span).mean(), label="Capacidad de memoria utilizada")
# plt.legend()
# plt.show()
